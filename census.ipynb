# %% [markdown]
# # census

# %%
# Importing required libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
#loading Dataset
df=pd.read_csv("census.csv")
df
# Out:
#        Age          Workclass  Fnlwgt      Education  Education_num  \
# 0       50   Self-emp-not-inc   83311      Bachelors             13
# 1       38            Private  215646        HS-grad              9
# 2       53            Private  234721           11th              7
# 3       28            Private  338409      Bachelors             13
# 4       37            Private  284582        Masters             14
# ...    ...                ...     ...            ...            ...
# 29016   27          Local-gov  137629        HS-grad              9
# 29017   42            Private  156526   Some-college             10
# 29018   26            Private  189238            9th              5
# 29019   23            Private  202989        HS-grad              9
# 29020   28            Private   25684        HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %%
df.shape
# Out:
# (29021, 15)

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
df.head()
# Out:
#    Age          Workclass  Fnlwgt   Education  Education_num  \
# 0   50   Self-emp-not-inc   83311   Bachelors             13
# 1   38            Private  215646     HS-grad              9
# 2   53            Private  234721        11th              7
# 3   28            Private  338409   Bachelors             13
# 4   37            Private  284582     Masters             14
#
#         Marital_status          Occupation    Relationship    Race      Sex  \
# 0   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 1             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 2   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 3   Married-civ-spouse      Prof-specialty            Wife   Black   Female
# 4   Married-civ-spouse     Exec-managerial            Wife   White   Female
#
#    Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# 0           0.0           0.0            13.0   United-States   <=50K
# ...

# %%
df.tail()
# Out:
#        Age   Workclass  Fnlwgt      Education  Education_num  \
# 29016   27   Local-gov  137629        HS-grad              9
# 29017   42     Private  156526   Some-college             10
# 29018   26     Private  189238            9th              5
# 29019   23     Private  202989        HS-grad              9
# 29020   28     Private   25684        HS-grad              9
#
#             Marital_status        Occupation    Relationship    Race      Sex  \
# 29016   Married-civ-spouse   Exec-managerial         Husband   White     Male
# 29017        Never-married      Tech-support   Not-in-family   White     Male
# 29018        Never-married     Other-service       Own-child   White   Female
# 29019        Never-married    Prof-specialty   Not-in-family   White     Male
# 29020        Never-married                               NaN     NaN      NaN
#
#        Capital_gain  Capital_loss  Hours_per_week  Native_country  Income
# ...

# %%
df.sample()
# Out:
#        Age Workclass  Fnlwgt Education  Education_num       Marital_status  \
# 27891   38   Private  192337      12th              8   Married-civ-spouse
#
#           Occupation Relationship    Race    Sex  Capital_gain  Capital_loss  \
# 27891   Craft-repair      Husband   White   Male           0.0           0.0
#
#        Hours_per_week  Native_country Income
# 27891            40.0   United-States   >50K

# %%
#checking datatype
df.dtypes
# Out:
# Age                 int64
# Workclass          object
# Fnlwgt              int64
# Education          object
# Education_num       int64
# Marital_status     object
# Occupation         object
# Relationship       object
# Race               object
# Sex                object
# Capital_gain      float64
# Capital_loss      float64
# Hours_per_week    float64
# Native_country     object
# Income             object
# dtype: object

# %%
#checking information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29021 entries, 0 to 29020
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             29021 non-null  int64
#  1   Workclass       29021 non-null  object
#  2   Fnlwgt          29021 non-null  int64
#  3   Education       29021 non-null  object
#  4   Education_num   29021 non-null  int64
#  5   Marital_status  29021 non-null  object
#  6   Occupation      29021 non-null  object
#  7   Relationship    29020 non-null  object
#  8   Race            29020 non-null  object
#  9   Sex             29020 non-null  object
#  10  Capital_gain    29020 non-null  float64
#  11  Capital_loss    29020 non-null  float64
#  12  Hours_per_week  29020 non-null  float64
#  13  Native_country  29020 non-null  object
#  14  Income          29020 non-null  object
# dtypes: float64(3), int64(3), object(9)
# memory usage: 3.3+ MB

# %%
#checking for null values
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      1
# Race              1
# Sex               1
# Capital_gain      1
# Capital_loss      1
# Hours_per_week    1
# Native_country    1
# Income            1
# dtype: int64

# %% [markdown]
# Observation :
#     1 null value is present in relationship, Race, Sex,Capital_gain, Capital_loss, Hours_per_week, Native_country,Income

# %%
#heatmap for null values
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
# create a boolean mask of null values
null_mask = df.isnull()

# check for any null values along each row
null_rows = null_mask.any(axis=1)

# print the rows that contain null values
print(df[null_rows])
# Out:
#        Age Workclass  Fnlwgt Education  Education_num  Marital_status  \
# 29020   28   Private   25684   HS-grad              9   Never-married
#
#       Occupation Relationship Race  Sex  Capital_gain  Capital_loss  \
# 29020                     NaN  NaN  NaN           NaN           NaN
#
#        Hours_per_week Native_country Income
# 29020             NaN            NaN    NaN

# %% [markdown]
# I found null value only on 29020 row, so I droped this row

# %%
df.drop(29020, inplace=True)

# %%
df.shape
# Out:
# (29020, 15)

# %%
#Again checking for null values
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# No null values is present

# %%
# checking for white space
# Iterate through each column of the dataframe and check for white spaces
for col in df.columns:
    # Count the number of white spaces in the column
    num_spaces = sum(df[col].astype(str).apply(lambda x: x.isspace()))

    # Display the results
    print(f"Column '{col}' has {num_spaces} white spaces.")
# Out:
# Column 'Age' has 0 white spaces.
# Column 'Workclass' has 0 white spaces.
# Column 'Fnlwgt' has 0 white spaces.
# Column 'Education' has 0 white spaces.
# Column 'Education_num' has 0 white spaces.
# Column 'Marital_status' has 0 white spaces.
# Column 'Occupation' has 0 white spaces.
# Column 'Relationship' has 0 white spaces.
# Column 'Race' has 0 white spaces.
# Column 'Sex' has 0 white spaces.
# Column 'Capital_gain' has 0 white spaces.
# Column 'Capital_loss' has 0 white spaces.
# Column 'Hours_per_week' has 0 white spaces.
# Column 'Native_country' has 0 white spaces.
# Column 'Income' has 0 white spaces.

# %% [markdown]
# no white space is present in dataset

# %%
# splitting the dataset in numerical and categorical dataset
# checking for categorical columns
categorical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        categorical_col.append(i)
print(categorical_col)
# Out:
# ['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']

# %%
# Now checking for numerical columns
numerical_col=[]
for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_col.append(i)
print(numerical_col)
# Out:
# ['Age', 'Fnlwgt', 'Education_num', 'Capital_gain', 'Capital_loss', 'Hours_per_week']

# %%
df.nunique()
# Out:
# Age                  72
# Workclass             9
# Fnlwgt            19932
# Education            16
# Education_num        16
# Marital_status        7
# Occupation           15
# Relationship          6
# Race                  5
# Sex                   2
# Capital_gain        118
# Capital_loss         90
# Hours_per_week       94
# Native_country       42
# Income                2
# dtype: int64

# %%
df['Workclass'].unique()
# Out:
# array([' Self-emp-not-inc', ' Private', ' State-gov', ' Federal-gov',
#        ' Local-gov', ' ?', ' Self-emp-inc', ' Without-pay',
#        ' Never-worked'], dtype=object)

# %%
# imputing the null values by most occuring value as these are categorical column
df['Workclass'] = df.Workclass.str.replace('?', 'Private')

# %% [markdown]
# I can make a group of
# 1. without pay and never worked as unemployed
# 2. Self-emp-not-inc and Self-emp-inc as bussiness
# 3. State-gov, Federal-gov, Local-gov as goverment sector

# %%
df.Workclass=df.Workclass.replace([' Local-gov',' State-gov',' Federal-gov'],' Govt-Sector')
df.Workclass=df.Workclass.replace([' Self-emp-not-inc',' Self-emp-inc'],' Bussiness')
df.Workclass=df.Workclass.replace([' Without-pay',' Never-worked'],'Umemployed')

# %%
df['Workclass'].unique()
# Out:
# array([' Bussiness', ' Private', ' Govt-Sector', 'Umemployed'],
#       dtype=object)

# %%
df['Education'].unique()
# Out:
# array([' Bachelors', ' HS-grad', ' 11th', ' Masters', ' 9th',
#        ' Some-college', ' Assoc-acdm', ' Assoc-voc', ' 7th-8th',
#        ' Doctorate', ' Prof-school', ' 5th-6th', ' 10th', ' 1st-4th',
#        ' Preschool', ' 12th'], dtype=object)

# %% [markdown]
# make a regrouping as school , high school, secondary school, under graduation , post graduation and phd

# %%
df["Education"]=df["Education"].replace([' Preschool',' 1st-4th',' 5th-6th',' 7th-8th',' 9th',' 10th',' 11th',' 12th'],'School')
df["Education"]=df["Education"].replace([' HS-grad',' Prof-school'],' High-School')
df["Education"]=df["Education"].replace([' Some-college',' Assoc-voc',' Assoc-acdm'],' Secondary-School')
df["Education"]=df["Education"].replace([' Bachelors',],' Under_Graduation')
df["Education"]=df["Education"].replace([' Masters'],'Post_Graduation')
df["Education"]=df["Education"].replace([' Doctorate'],' PhD')

# %%
df['Education'].unique()
# Out:
# array([' Under_Graduation', ' High-School', 'School', 'Post_Graduation',
#        ' Secondary-School', ' PhD'], dtype=object)

# %%
df['Marital_status'].unique()
# Out:
# array([' Married-civ-spouse', ' Divorced', ' Married-spouse-absent',
#        ' Never-married', ' Separated', ' Married-AF-spouse', ' Widowed'],
#       dtype=object)

# %% [markdown]
# making a group of married , single, others

# %%
df["Marital_status"]=df["Marital_status"].replace([' Married-civ-spouse',' Married-AF-spouse'],' Married')
df["Marital_status"]=df["Marital_status"].replace([' Never-married'],' Single')
df["Marital_status"]=df["Marital_status"].replace([' Divorced',' Widowed',' Separated',' Married-spouse-absent',],' Others')

# %%
df['Marital_status'].unique()
# Out:
# array([' Married', ' Others', ' Single'], dtype=object)

# %%
df['Relationship'].unique()
# Out:
# array([' Husband', ' Not-in-family', ' Wife', ' Own-child', ' Unmarried',
#        ' Other-relative'], dtype=object)

# %%
df['Occupation'].unique()
# Out:
# array([' Exec-managerial', ' Handlers-cleaners', ' Prof-specialty',
#        ' Other-service', ' Adm-clerical', ' Sales', ' Craft-repair',
#        ' Transport-moving', ' Farming-fishing', ' Machine-op-inspct',
#        ' Tech-support', ' ?', ' Protective-serv', ' Armed-Forces',
#        ' Priv-house-serv'], dtype=object)

# %%
# imputing the null values by most occuring value as these are categorical column
df['Occupation'] = df.Occupation.str.replace('?', 'Private')

# %%
df['Race'].unique()
# Out:
# array([' White', ' Black', ' Asian-Pac-Islander', ' Amer-Indian-Eskimo',
#        ' Other'], dtype=object)

# %% [markdown]
# # Visualization

# %% [markdown]
# ### univariant visualization

# %%
plt.figure(figsize=(20,20))
plt.subplot(5,2,1)
# Add axis labels and title
plt.xlabel('Workclass')
plt.ylabel('Count')
sns.countplot(df["Workclass"])

plt.subplot(5,2,2)
# Add axis labels and title
plt.xlabel('Education')
plt.ylabel('Count')
sns.countplot(df["Education"])


plt.subplot(5,2,3)
# Add axis labels and title
plt.xlabel('Marital_status')
plt.ylabel('Count')
sns.countplot(df["Marital_status"])



plt.subplot(5,2,4)
# Add axis labels and title
plt.xlabel('Occupation')
plt.ylabel('Count')
sns.countplot(df["Occupation"])


plt.subplot(5,2,5)
# Add axis labels and title
plt.xlabel('Relationship')
plt.ylabel('Count')
sns.countplot(df["Relationship"])


plt.subplot(5,2,6)
# Add axis labels and title
plt.xlabel('Race')
plt.ylabel('Count')
sns.countplot(df["Race"])


plt.subplot(5,2,7)
# Add axis labels and title
plt.xlabel('Sex')
plt.ylabel('Count')
sns.countplot(df["Sex"])


plt.subplot(5,2,8)
# Add axis labels and title
plt.xlabel('Native_country')
plt.ylabel('Count')
sns.countplot(df["Native_country"])


plt.subplot(5,2,9)
# Add axis labels and title
plt.xlabel('Income')
plt.ylabel('Count')
sns.countplot(df["Income"])


# Display the plot
plt.show()

# %% [markdown]
# Observation:
# 1. privatly working people is higher and followed by goverment sector and bussiness
# 2. In term of education high schooling people are more followed by under graduation.
# 3. married people are high than single person
# 4. The people who are in the position of Prof-speciality have highest count and the people in the position Armed-Forces have very least counts.
# 5. The count is high in the Husband category is high and other relative has very least.
# 6. White race category is higher in count.
# 7. Male are counted more than female
# 8. United state people are more in number.
# 9. Income is less than 50 k peoples are high in number

# %% [markdown]
# ### Bivarient analysis

# %% [markdown]
# ### Checking the relation between target Income and variaus input column

# %%
plt.figure(figsize=[6,3])
plt.title('Comparision between Age and Income')
sns.barplot(df['Age'],df["Income"])
# Out:
# <AxesSubplot:title={'center':'Comparision between Age and Income'}, xlabel='Age', ylabel='Income'>

# %% [markdown]
# people who has higher age have income greater than 50k

# %%
plt.figure(figsize=[6,3])
plt.title('Comparision between Workclass and Income')
sns.countplot(df['Workclass'],hue=df["Income"])
# Out:
# <AxesSubplot:title={'center':'Comparision between Workclass and Income'}, xlabel='Workclass', ylabel='count'>

# %% [markdown]
# private working people have income less than 50k

# %%
plt.figure(figsize=[10,5])
plt.title('Comparision between Education and Income')
sns.countplot(df['Education'],hue=df["Income"])
# Out:
# <AxesSubplot:title={'center':'Comparision between Education and Income'}, xlabel='Education', ylabel='count'>

# %% [markdown]
# high school people have higher in number in income less than 50k

# %%
plt.figure(figsize=[6,3])
plt.title('Comparision between Marital_status and Income')
sns.countplot(df['Marital_status'],hue=df["Income"])
# Out:
# <AxesSubplot:title={'center':'Comparision between Marital_status and Income'}, xlabel='Marital_status', ylabel='count'>

# %% [markdown]
# single people are high in number in income less than 50k

# %%
plt.figure(figsize=[20,10])
plt.title('Comparision between Occupation and Income')
sns.countplot(df['Occupation'],hue=df["Income"])
# Out:
# <AxesSubplot:title={'center':'Comparision between Occupation and Income'}, xlabel='Occupation', ylabel='count'>

# %% [markdown]
# Population belonging to Prof-speciality and Exce-managerial have the income more than 50K.

# %%
plt.figure(figsize=[6,3])
plt.title('Comparision between Relationship and Income')
sns.countplot(df['Relationship'],hue=df["Income"])
# Out:
# <AxesSubplot:title={'center':'Comparision between Relationship and Income'}, xlabel='Relationship', ylabel='count'>

# %% [markdown]
# Population in relationship as Husband has relatively higher income

# %%
plt.figure(figsize=[6,3])
plt.title('Comparision between Fnlwgt and Income')
sns.barplot(df['Fnlwgt'],df["Income"])
# Out:
# <AxesSubplot:title={'center':'Comparision between Fnlwgt and Income'}, xlabel='Fnlwgt', ylabel='Income'>

# %% [markdown]
# no significationt relationship is found here

# %%
plt.figure(figsize=[6,3])
plt.title('Comparision between Race and Income')
sns.countplot(df['Race'],hue=df["Income"])
# Out:
# <AxesSubplot:title={'center':'Comparision between Race and Income'}, xlabel='Race', ylabel='count'>

# %% [markdown]
# white people have income less than 50k

# %%
plt.figure(figsize=[6,3])
plt.title('Comparision between Sex and Income')
sns.countplot(df['Sex'],hue=df["Income"])
# Out:
# <AxesSubplot:title={'center':'Comparision between Sex and Income'}, xlabel='Sex', ylabel='count'>

# %% [markdown]
# The income of Male is above 50K is high compared to the female.

# %%
plt.figure(figsize=[6,3])
plt.title('Comparision between Capital_gain and Income')
sns.barplot(df['Capital_gain'],df["Income"])
# Out:
# <AxesSubplot:title={'center':'Comparision between Capital_gain and Income'}, xlabel='Capital_gain', ylabel='Income'>

# %% [markdown]
# when capital gain is high income is greater than 50k

# %%
plt.figure(figsize=[6,3])
plt.title('Comparision between Capital_loss and Income')
sns.barplot(df['Capital_loss'],df["Income"])
# Out:
# <AxesSubplot:title={'center':'Comparision between Capital_loss and Income'}, xlabel='Capital_loss', ylabel='Income'>

# %% [markdown]
# when capital loss is high income greater than 50 k is high

# %%
plt.figure(figsize=[6,3])
plt.title('Comparision between Hours_per_week and Income')
sns.barplot(df['Hours_per_week'],df["Income"])
# Out:
# <AxesSubplot:title={'center':'Comparision between Hours_per_week and Income'}, xlabel='Hours_per_week', ylabel='Income'>

# %% [markdown]
# The income is >50K when the Hours is high

# %%
plt.figure(figsize=[20,10])
plt.title('Comparision between Native_country and Income')
sns.countplot(df['Native_country'],hue=df["Income"])
# Out:
# <AxesSubplot:title={'center':'Comparision between Native_country and Income'}, xlabel='Native_country', ylabel='count'>

# %% [markdown]
# Clearly United States earning more income compared to all the other countries.

# %% [markdown]
# ### multivarient analysis

# %%
# Checking the pairwise relation in the dataset.
sns.pairplot(df,hue="Income")

# %% [markdown]
# ### statistical summary

# %%
# statistical summary of numerical columns
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  29020.000000  2.902000e+04   29020.000000  29020.000000  29020.000000
# mean      38.603101  1.897851e+05      10.078222   1098.483770     86.832391
# std       13.663651  1.052724e+05       2.573034   7529.847857    402.017579
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178638e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.784960e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.372398e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    29020.000000
# mean        40.417333
# std         12.295853
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# statistical summary of categorical columns
df.describe(include=['O'])
# Out:
#        Workclass     Education Marital_status       Occupation Relationship  \
# count      29020         29020          29020            29020        29020
# unique         4             6              3               15            6
# top      Private   High-School        Married   Prof-specialty      Husband
# freq       21838          9890          13329             3680        11728
#
#           Race    Sex  Native_country  Income
# count    29020  29020           29020   29020
# unique       5      2              42       2
# top      White   Male   United-States   <=50K
# freq     24780  19425           25985   22051

# %%
# visualize df.describe
plt.figure(figsize=(22,15))
sns.heatmap(df.describe(),annot=True,linewidth=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
#converting categorical data into numerical data
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
cols=['Workclass', 'Education', 'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex', 'Native_country', 'Income']
df[cols] = df[cols].apply(LabelEncoder().fit_transform)
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          0   83311          3             13               0
# 1       38          2  215646          0              9               1
# 2       53          2  234721          5              7               0
# 3       28          2  338409          3             13               0
# 4       37          2  284582          4             14               0
# ...    ...        ...     ...        ...            ...             ...
# 29015   44          1  357814          5              8               0
# 29016   27          1  137629          0              9               0
# 29017   42          2  156526          2             10               2
# 29018   26          2  189238          5              5               2
# 29019   23          2  202989          0              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
#  again visualize df.describe
plt.figure(figsize=(22,15))
sns.heatmap(df.describe(),annot=True,linewidth=0.1,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %%
#correlation
df.corr()
# Out:
#                      Age  Workclass    Fnlwgt  Education  Education_num  \
# Age             1.000000  -0.202502 -0.077271  -0.000873       0.036002
# Workclass      -0.202502   1.000000  0.047355   0.010275      -0.134710
# Fnlwgt         -0.077271   0.047355  1.000000   0.018510      -0.044997
# Education      -0.000873   0.010275  0.018510   1.000000      -0.093074
# Education_num   0.036002  -0.134710 -0.044997  -0.093074       1.000000
# Marital_status -0.461627   0.175162  0.033068   0.037770      -0.065364
# Occupation      0.005944   0.002679  0.000163   0.069727       0.096016
# Relationship   -0.259862   0.124518  0.008466  -0.001617      -0.094574
# Race            0.025222  -0.025699 -0.018962  -0.006811       0.031702
# Sex             0.085912  -0.112098  0.028255   0.005112       0.013709
# Capital_gain    0.077511  -0.072651  0.001657  -0.009393       0.123467
# Capital_loss    0.057412  -0.044173 -0.012272   0.006229       0.079585
# ...

# %%
# visualize the correlation
plt.figure(figsize=(20,15))
sns.heatmap(df.corr(),linewidths=0.1,fmt='0.2f',annot=True)
# Out:
# <AxesSubplot:>

# %%
# correlation of column with target column
df.corr()["Income"].sort_values()
# Out:
# Marital_status   -0.422766
# Relationship     -0.250199
# Workclass        -0.133237
# Fnlwgt           -0.008892
# Native_country    0.017756
# Education         0.026565
# Occupation        0.051545
# Race              0.073463
# Capital_loss      0.146465
# Sex               0.216431
# Capital_gain      0.223602
# Hours_per_week    0.228355
# Age               0.232615
# Education_num     0.334927
# Income            1.000000
# Name: Income, dtype: float64

# %%
plt.figure(figsize=(22,7))
df.corr()['Income'].sort_values(ascending=False).drop(['Income']).plot(kind='bar')
plt.xlabel('Values',fontsize=14)
plt.ylabel('Income',fontsize=14)
plt.title('corelation',fontsize=16)
plt.show()

# %%
df["Income"].unique()
# Out:
# array([0, 1])

# %%
# skewness
df.skew()
# Out:
# Age                0.564338
# Workclass         -1.609108
# Fnlwgt             1.447133
# Education          0.330113
# Education_num     -0.307199
# Marital_status     0.257913
# Occupation         0.091804
# Relationship       0.786732
# Race              -2.433056
# Sex               -0.720067
# Capital_gain      11.765053
# Capital_loss       4.606400
# Hours_per_week     0.227067
# Native_country    -3.653047
# Income             1.216696
# dtype: float64

# %%
#Checking the Distribution on the DataSet on numerical column
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1
for column in numerical_col:
    if plotnumber<=12:
        ax=plt.subplot(3,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column,fontsize=20)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# skeweness is present in all columns

# %%
# checking for outliers

numerical_col=df[numerical_col]
plt.figure(figsize=(20,18))
for i, column in enumerate(numerical_col, 1):
    plt.subplot(4,4,i)
    sns.boxplot(df[column])

# %% [markdown]
# outliers are present in all columns

# %%
# Outlier removing
df.shape
# Out:
# (29020, 15)

# %%
df.sample()
# Out:
#       Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 8764   23          1  101094          2             10               2
#
#       Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# 8764          11             3     4    1           0.0           0.0
#
#       Hours_per_week  Native_country  Income
# 8764            60.0              39       0

# %%
from scipy.stats import zscore
z = np.abs(zscore(numerical_col))
z
# Out:
#             Age    Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# 0      0.834118  1.011432       1.135558      0.145886      0.215995
# 1      0.044140  0.245661       0.419054      0.145886      0.215995
# 2      1.053682  0.426861       1.196360      0.145886      0.215995
# 3      0.776021  1.411827       1.135558      0.145886      0.215995
# 4      0.117328  0.900507       1.524210      0.145886      0.215995
# ...         ...       ...            ...           ...           ...
# 29015  0.394989  1.596161       0.807707      0.145886      0.215995
# 29016  0.849209  0.495448       0.419054      0.145886      0.215995
# 29017  0.248613  0.315939       0.030401      0.145886      0.215995
# 29018  0.922398  0.005197       1.973666      0.145886      0.215995
# 29019  1.141962  0.125428       0.419054      0.145886      0.215995
#
#        Hours_per_week
# 0            2.229842
# 1            0.033942
# 2            0.033942
# 3            0.033942
# ...

# %%
threshold=3
np.where(z>3)
# Out:
# (array([    9,    22,    27, ..., 28956, 28986, 29016], dtype=int64),
#  array([5, 4, 5, ..., 1, 4, 5], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]
df_new
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50          0   83311          3             13               0
# 1       38          2  215646          0              9               1
# 2       53          2  234721          5              7               0
# 3       28          2  338409          3             13               0
# 4       37          2  284582          4             14               0
# ...    ...        ...     ...        ...            ...             ...
# 29014   35          2  194960          0              9               2
# 29015   44          1  357814          5              8               0
# 29017   42          2  156526          2             10               2
# 29018   26          2  189238          5              5               2
# 29019   23          2  202989          0              9               2
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %%
df_new.shape
# Out:
# (26597, 15)

# %%
#data loss in percentage
Data_loss =((df.shape[0]-df_new.shape[0])/df.shape[0])*100
Data_loss
# Out:
# 8.349414197105444

# %% [markdown]
# here % loss is not greater than 10% so we can accept this value.

# %% [markdown]
# ### using IQR

# %%
from scipy import stats

# %%
IQR=stats.iqr(numerical_col)
IQR
# Out:
# 50.0

# %%
Q1=numerical_col.quantile(0.25)
Q3=numerical_col.quantile(0.75)
IQR = numerical_col[~ ((numerical_col < (Q1 -1.5 * IQR)) |(numerical_col > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
print("shape of original dataframe: ",df.shape)
print("shape of dataframe using zscore: ",IQR.shape)
print("removal of rows: ",df.shape[0]-IQR.shape[0])
# Out:
# shape of original dataframe:  (29020, 15)
# shape of dataframe using zscore:  (12592, 6)
# removal of rows:  16428

# %%
# checking the data loss after removing outliers
data_loss = (29020-12592)/29020*100
data_loss
# Out:
# 56.6092350103377

# %% [markdown]
# I can not accept this removal method as data loss is higher here

# %%
#checking skewness for new dataset
df_new.skew()
# Out:
# Age                0.495600
# Workclass         -1.658647
# Fnlwgt             0.626663
# Education          0.346381
# Education_num     -0.171476
# Marital_status     0.217880
# Occupation         0.100031
# Relationship       0.743160
# Race              -2.436426
# Sex               -0.680335
# Capital_gain       4.971527
# Capital_loss      29.141865
# Hours_per_week    -0.354613
# Native_country    -3.733963
# Income             1.333100
# dtype: float64

# %%
# Removing skewness using yeo-johnson  method to get better prediction
from sklearn.preprocessing import PowerTransformer
scaler = PowerTransformer(method='yeo-johnson')
df_new = scaler.fit_transform(df_new)

# %%
df_new=df = pd.DataFrame(df_new)

# %%
df_new.skew()
# Out:
# 0     -0.016692
# 1     -0.955363
# 2     -0.035276
# 3     -0.111163
# 4      0.022572
# 5      0.022017
# 6     -0.214568
# 7      0.103757
# 8     -2.004969
# 9     -0.680335
# 10     3.079382
# 11    24.526451
# 12     0.110369
# 13    -2.781628
# 14     1.333100
# dtype: float64

# %%
x=df.iloc[:,:-1]

# %%
y=df.loc[:, ['Income']]

# %%
x.shape
# Out:
# (29020, 14)

# %%
y.shape
# Out:
# (29020, 1)

# %% [markdown]
# ### scaling

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)
x
# Out:
#             Age  Workclass    Fnlwgt  Education  Education_num  \
# 0      0.834118  -2.424495 -1.011432   0.602583       1.135558
# 1     -0.044140   0.531324  0.245661  -1.150437      -0.419054
# 2      1.053682   0.531324  0.426861   1.771263      -1.196360
# 3     -0.776021   0.531324  1.411827   0.602583       1.135558
# 4     -0.117328   0.531324  0.900507   1.186923       1.524210
# ...         ...        ...       ...        ...            ...
# 29015  0.394989  -0.946585  1.596161   1.771263      -0.807707
# 29016 -0.849209  -0.946585 -0.495448  -1.150437      -0.419054
# 29017  0.248613   0.531324 -0.315939   0.018243      -0.030401
# 29018 -0.922398   0.531324 -0.005197   1.771263      -1.973666
# 29019 -1.141962   0.531324  0.125428  -1.150437      -0.419054
#
#        Marital_status  Occupation  Relationship      Race       Sex  \
# 0           -0.989935   -0.793858     -0.901135  0.394149  0.702817
# 1            0.149609   -0.335327     -0.278405  0.394149  0.702817
# ...

# %% [markdown]
# ### oversampling data using SMOTE

# %%
# oversampling data
from imblearn.over_sampling import SMOTE
smt=SMOTE()

# %%
x,y=smt.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# Income
# 0         22051
# 1         22051
# dtype: int64

# %% [markdown]
# ### Checking VIF Values

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = pd.DataFrame()
vif["VIF values"] = [variance_inflation_factor(x.values,i)
              for i in range(len(x.columns))]
vif["Features"] = x.columns

# Let's check the values
vif
# Out:
#     VIF values        Features
# 0     1.336974             Age
# 1     1.087635       Workclass
# 2     1.011692          Fnlwgt
# 3     1.013366       Education
# 4     1.125289   Education_num
# 5     1.572935  Marital_status
# 6     1.022357      Occupation
# 7     2.067459    Relationship
# 8     1.043081            Race
# 9     1.912265             Sex
# 10    1.049473    Capital_gain
# 11    1.029483    Capital_loss
# 12    1.172324  Hours_per_week
# 13    1.032597  Native_country

# %% [markdown]
# not a single column have vif value grater than 10 , so multicoliarity was not present

# %% [markdown]
# ### model building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.model_selection import cross_val_score

# %% [markdown]
# Finding best random state

# %%
maxAccu=0
maxRS=0
for i in range(1,200):
    x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30, random_state =i)
    DTC = DecisionTreeClassifier()
    DTC.fit(x_train, y_train)
    pred = DTC.predict(x_test)
    acc=accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print("Best accuracy is ",maxAccu," on Random_state ",maxRS)
# Out:
# Best accuracy is  0.8625954198473282  on Random_state  41

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.30, random_state =41)

# %% [markdown]
# ### Logistic Regression

# %%
#cross validation score for logistic regresson
logreg=LogisticRegression()
logreg.fit(x_train,y_train)
LR_predicted=logreg.predict(x_test)
lss=accuracy_score(y_test,LR_predicted)
for j in range(2,10):
    lssscore=cross_val_score(logreg,x,y,cv=j)
    lsc=lssscore.mean()
    print("At CV:",j)
    print("Cross validation score is:",lsc*100)
    print("Accuracy score is:",lss*100)
# Out:
# At CV: 2
# Cross validation score is: 81.07795564826992
# Accuracy score is: 81.4904391202479
# At CV: 3
# Cross validation score is: 81.08930131243483
# Accuracy score is: 81.4904391202479
# At CV: 4
# Cross validation score is: 81.09611234299634
# Accuracy score is: 81.4904391202479
# At CV: 5
# Cross validation score is: 81.13466266981418
# Accuracy score is: 81.4904391202479
# At CV: 6
# Cross validation score is: 81.07797140531268
# Accuracy score is: 81.4904391202479
# At CV: 7
# Cross validation score is: 81.09612158887785
# Accuracy score is: 81.4904391202479
# At CV: 8
# Cross validation score is: 81.10291437088797
# Accuracy score is: 81.4904391202479
# At CV: 9
# Cross validation score is: 81.09386024694855
# Accuracy score is: 81.4904391202479

# %% [markdown]
# I select cv=5

# %%
logreg_score=cross_val_score(logreg,x_train,y_train,cv=5,scoring='accuracy')

LR_predicted=logreg.predict(x_test)

print(confusion_matrix(y_test,LR_predicted))
print(classification_report(y_test,LR_predicted))
print("Training accuracy::",logreg.score(x_train,y_train))
print("Test accuracy::",logreg.score(x_test,y_test))
print("accuracy",accuracy_score(y_test,LR_predicted))
print("cross validation score:",np.mean(logreg_score))
# Out:
# [[5216 1438]
#  [1011 5566]]
#               precision    recall  f1-score   support
#
#            0       0.84      0.78      0.81      6654
#            1       0.79      0.85      0.82      6577
#
#     accuracy                           0.81     13231
#    macro avg       0.82      0.82      0.81     13231
# weighted avg       0.82      0.81      0.81     13231
#
# Training accuracy:: 0.8097243367561789
# Test accuracy:: 0.814904391202479
# accuracy 0.814904391202479
# cross validation score: 0.8097892140083334

# %%
# Lets plot confusion matrix for Logistic Regression
cm = confusion_matrix(y_test,LR_predicted)

x_axis_labels = ["0","1"]
y_axis_labels = ["1","0"]

f , ax = plt.subplots(figsize=(7,7))
sns.heatmap(cm, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, cmap="BuGn",xticklabels=x_axis_labels,yticklabels=y_axis_labels)

plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Logistic Regression Classifier')
plt.show()

# %% [markdown]
# ### decision tree classifier

# %%
dtc=DecisionTreeClassifier()
dtc_score=cross_val_score(dtc,x,y,cv=5,scoring='accuracy')

dtc.fit(x_train,y_train)
predicted_dtc=dtc.predict(x_test)

print(confusion_matrix(y_test,predicted_dtc))
print(classification_report(y_test,predicted_dtc))
print("Training accuracy::",dtc.score(x_train,y_train))
print("Test accuracy::",dtc.score(x_test,y_test))
print("cross validation score for svm:",np.mean(dtc_score))
print("accuracy",accuracy_score(y_test,predicted_dtc))
# Out:
# [[5688  966]
#  [ 833 5744]]
#               precision    recall  f1-score   support
#
#            0       0.87      0.85      0.86      6654
#            1       0.86      0.87      0.86      6577
#
#     accuracy                           0.86     13231
#    macro avg       0.86      0.86      0.86     13231
# weighted avg       0.86      0.86      0.86     13231
#
# Training accuracy:: 1.0
# Test accuracy:: 0.8640314413120701
# cross validation score for svm: 0.8539545266770882
# accuracy 0.8640314413120701

# %%
# Lets plot confusion matrix for DecisionTreeClassifier
cm = confusion_matrix(y_test,predicted_dtc)

x_axis_labels = ["0","1"]
y_axis_labels = ["1","0"]

f , ax = plt.subplots(figsize=(7,7))
sns.heatmap(cm, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, cmap="BuGn",xticklabels=x_axis_labels,yticklabels=y_axis_labels)

plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for DecisionTreeClassifier')
plt.show()

# %% [markdown]
# ### KNeighborsClassifier

# %%
knn=KNeighborsClassifier()
knn_score=cross_val_score(knn,x,y,cv=5,scoring='accuracy')

knn.fit(x_train,y_train)
predicted_knn=knn.predict(x_test)

print(confusion_matrix(y_test,predicted_knn))
print(classification_report(y_test,predicted_knn))
print("Training accuracy::",knn.score(x_train,y_train))
print("Test accuracy::",knn.score(x_test,y_test))
print("cross validation score for knn:",np.mean(knn_score))
print("accuracy",accuracy_score(y_test,predicted_knn))
# Out:
# [[5202 1452]
#  [ 455 6122]]
#               precision    recall  f1-score   support
#
#            0       0.92      0.78      0.85      6654
#            1       0.81      0.93      0.87      6577
#
#     accuracy                           0.86     13231
#    macro avg       0.86      0.86      0.86     13231
# weighted avg       0.86      0.86      0.86     13231
#
# Training accuracy:: 0.895565417382009
# Test accuracy:: 0.8558687929861688
# cross validation score for knn: 0.8616395578372679
# accuracy 0.8558687929861688

# %%
# Lets plot confusion matrix 
cm = confusion_matrix(y_test,predicted_knn)

x_axis_labels = ["0","1"]
y_axis_labels = ["1","0"]

f , ax = plt.subplots(figsize=(7,7))
sns.heatmap(cm, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, cmap="BuGn",xticklabels=x_axis_labels,yticklabels=y_axis_labels)

plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for KNeighborsClassifier')
plt.show()

# %% [markdown]
# ### RandomForestClassifier

# %%
rfc=RandomForestClassifier()
rfc_score=cross_val_score(rfc,x,y,cv=5,scoring='accuracy')

rfc.fit(x_train,y_train)
predicted_rfc=rfc.predict(x_test)

print(confusion_matrix(y_test,predicted_rfc))
print(classification_report(y_test,predicted_rfc))
print("Training accuracy::",rfc.score(x_train,y_train))
print("Test accuracy::",rfc.score(x_test,y_test))
print("cross validation score for Ada boost:",np.mean(rfc_score))
print("accuracy",accuracy_score(y_test,predicted_rfc))
# Out:
# [[5903  751]
#  [ 558 6019]]
#               precision    recall  f1-score   support
#
#            0       0.91      0.89      0.90      6654
#            1       0.89      0.92      0.90      6577
#
#     accuracy                           0.90     13231
#    macro avg       0.90      0.90      0.90     13231
# weighted avg       0.90      0.90      0.90     13231
#
# Training accuracy:: 1.0
# Test accuracy:: 0.9010656790869926
# cross validation score for Ada boost: 0.8995530198626704
# accuracy 0.9010656790869926

# %%
# Lets plot confusion matrix 
cm = confusion_matrix(y_test,predicted_rfc)

x_axis_labels = ["0","1"]
y_axis_labels = ["1","0"]

f , ax = plt.subplots(figsize=(7,7))
sns.heatmap(cm, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, cmap="BuGn",xticklabels=x_axis_labels,yticklabels=y_axis_labels)

plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for RandomForestClassifier')
plt.show()

# %% [markdown]
# From the analysis of the model accuracy and cross val accuracy score we see that 'RandomForestClassifier' is the best model

# %% [markdown]
# ### Ensemble method

# %% [markdown]
# ### ADA BOOST CLASSIFIER

# %%
adb=AdaBoostClassifier()
adb_score=cross_val_score(adb,x,y,cv=5,scoring='accuracy')

adb.fit(x_train,y_train)
predicted_adb=adb.predict(x_test)

print(confusion_matrix(y_test,predicted_adb))
print(classification_report(y_test,predicted_adb))
print("Training accuracy::",adb.score(x_train,y_train))
print("Test accuracy::",adb.score(x_test,y_test))
print("cross validation score for Ada boost:",np.mean(adb_score))
print("accuracy",accuracy_score(y_test,predicted_adb))
# Out:
# [[5500 1154]
#  [ 767 5810]]
#               precision    recall  f1-score   support
#
#            0       0.88      0.83      0.85      6654
#            1       0.83      0.88      0.86      6577
#
#     accuracy                           0.85     13231
#    macro avg       0.86      0.85      0.85     13231
# weighted avg       0.86      0.85      0.85     13231
#
# Training accuracy:: 0.8493408052865149
# Test accuracy:: 0.8548106719068853
# cross validation score for Ada boost: 0.8502118141592124
# accuracy 0.8548106719068853

# %%
# Lets plot confusion matrix 
cm = confusion_matrix(y_test,predicted_adb)

x_axis_labels = ["0","1"]
y_axis_labels = ["1","0"]

f , ax = plt.subplots(figsize=(7,7))
sns.heatmap(cm, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, cmap="BuGn",xticklabels=x_axis_labels,yticklabels=y_axis_labels)

plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for AdaBoostClassifier')
plt.show()

# %% [markdown]
# ### Gradient Boosting classifier

# %%
grbc=GradientBoostingClassifier()
grbc_score=cross_val_score(grbc,x,y,cv=5,scoring='accuracy')

grbc.fit(x_train,y_train)
predicted_grbc=grbc.predict(x_test)

print(confusion_matrix(y_test,predicted_grbc))
print(classification_report(y_test,predicted_grbc))
print("Training accuracy::",grbc.score(x_train,y_train))
print("Test accuracy::",grbc.score(x_test,y_test))
print("cross validation score for Gradient Boosting Classifier:",np.mean(grbc_score))
print("accuracy",accuracy_score(y_test,predicted_grbc))
# Out:
# [[5571 1083]
#  [ 662 5915]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.84      0.86      6654
#            1       0.85      0.90      0.87      6577
#
#     accuracy                           0.87     13231
#    macro avg       0.87      0.87      0.87     13231
# weighted avg       0.87      0.87      0.87     13231
#
# Training accuracy:: 0.8677723429756081
# Test accuracy:: 0.8681127654750208
# cross validation score for Gradient Boosting Classifier: 0.862773935935709
# accuracy 0.8681127654750208

# %%
# Lets plot confusion matrix 
cm = confusion_matrix(y_test,predicted_grbc)

x_axis_labels = ["0","1"]
y_axis_labels = ["1","0"]

f , ax = plt.subplots(figsize=(7,7))
sns.heatmap(cm, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, cmap="BuGn",xticklabels=x_axis_labels,yticklabels=y_axis_labels)

plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for Gradient Boosting classifier')
plt.show()

# %% [markdown]
# ### BAGGING CLASSIFIER

# %%
bgc=BaggingClassifier()
bgc_score=cross_val_score(bgc,x,y,cv=5,scoring='accuracy')
bgc.fit(x_train,y_train)
predicted_bgc=bgc.predict(x_test)
print(accuracy_score(y_test,predicted_bgc))
print(confusion_matrix(y_test,predicted_bgc))
print(classification_report(y_test,predicted_bgc))
print("Training accuracy::",bgc.score(x_train,y_train))
print("Test accuracy::",bgc.score(x_test,y_test))
print("cross validation score for BAGGING Classifier:",np.mean(bgc_score))
# Out:
# 0.8888217065981407
# [[5952  702]
#  [ 769 5808]]
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89      6654
#            1       0.89      0.88      0.89      6577
#
#     accuracy                           0.89     13231
#    macro avg       0.89      0.89      0.89     13231
# weighted avg       0.89      0.89      0.89     13231
#
# Training accuracy:: 0.9931327135499336
# Test accuracy:: 0.8888217065981407
# cross validation score for BAGGING Classifier: 0.8835225308806212

# %%
# Lets plot confusion matrix 
cm = confusion_matrix(y_test,predicted_bgc)

x_axis_labels = ["0","1"]
y_axis_labels = ["1","0"]

f , ax = plt.subplots(figsize=(7,7))
sns.heatmap(cm, annot = True,linewidths=.2, linecolor="black", fmt = ".0f", ax=ax, cmap="BuGn",xticklabels=x_axis_labels,yticklabels=y_axis_labels)

plt.xlabel("PREDICTED LABEL")
plt.ylabel("TRUE LABEL")
plt.title('Confusion Matrix for BaggingClassifier')
plt.show()

# %% [markdown]
#  I choose BaggingClassifier foe ensembling

# %% [markdown]
# ### Hyperparameter Tuning

# %%
# Initialize Bagging classifier with a Random Forest base estimator
bgc = BaggingClassifier(base_estimator=RandomForestClassifier())

# Define the parameter grid to search over
param_grid = {
    'base_estimator__n_estimators': [100, 200, 300],
    'base_estimator__max_depth': [5, 10, 15],
    'n_estimators': [10, 20, 30]
}

# Perform a grid search with cross-validation to find the best hyperparameters
grid_search = GridSearchCV(estimator=bc, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)

# Print the best hyperparameters found by the grid search
print("Best hyperparameters:", grid_search.best_params_)

# Make predictions on the testing data using the best model
y_pred = grid_search.predict(X_test)

# Evaluate the performance of the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# %%
# Initialize Bagging classifier with a Random Forest base estimator
bgc = BaggingClassifier(base_estimator=RandomForestClassifier())

# %%
# Define the parameter grid to search over
param_grid = {
    'base_estimator__n_estimators': [100, 200, 300],
    'base_estimator__max_depth': [5, 10, 15],
    'n_estimators': [10, 20, 30]
}

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameters,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestClassifier(),
#              param_grid={'criterion': ['gini'], 'max_depth': [2, 3, 4, 5, 6, 8],
#                          'max_features': ['auto'], 'n_estimators': [0, 200]})

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 8,
#  'max_features': 'auto',
#  'n_estimators': 200}

# %%
census = RandomForestClassifier (criterion='gini', max_depth=8, max_features='auto', n_estimators=200)
census.fit(x_train, y_train)
pred = census.predict(x_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 84.64968634268007

# %% [markdown]
# got accuracy of 84.64% after hyperpaarameter tuning

# %% [markdown]
# ### roc auc curve

# %%
from sklearn.metrics import roc_auc_score

# %%
print("roc auc score::",roc_auc_score(y_test, pred))
# Out:
# roc auc score:: 0.846898540098317

# %%
from sklearn.metrics import roc_curve

# %%
fpr1, tpr1, thresh1 = roc_curve(y_test,pred, pos_label=1)

# %%
#plotting ROC CURVE
sns.set_theme(style="darkgrid")
plt.plot(fpr1, tpr1, linestyle='--',color='red', label='Random Forest classifier')

plt.title('ROC curve')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive rate')
plt.legend(loc='best')

# %% [markdown]
# ### Saving model

# %%
#importing library
import joblib
#saving the model
joblib.dump(rfc,'census.pkl')
# Out:
# ['census.pkl']
